# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup
import torch
from transformers import BartForConditionalGeneration, BartTokenizer

# %% [markdown]
# ## Parsing data from Website

# %%
webUrl = "https://www.hindustantimes.com/india-news"
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; ARM64 Mac OS X 14_0; rv:97.0) Gecko/20100101 Firefox/97.0'}

r = requests.get(webUrl, headers = headers)
htmlContent = r.content

soup = BeautifulSoup(htmlContent, 'html.parser')
time.sleep(5)

# %% [markdown]
# ## Finding Links for Summaries

# %%
news = soup.find('section', class_ = 'listingPage').find_all('div', class_ = 'cartHolder bigCart track timeAgo') + soup.find('section', class_ = 'listingPage').find_all('div', class_ = 'cartHolder listView track timeAgo')

newsList = []
for div in news:
    newsList.append(div.get('data-weburl'))

# %% [markdown]
# ## BART Model initialized

# %%
model_name = 'facebook/bart-large-cnn'
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)

# %% [markdown]
# ## Function for Summary Generation

# %%
def gen_summary(text):
    # Tokenize the input text
    input_ids = tokenizer.encode(text, truncation=True, padding='longest', return_tensors='pt')

    # Generate the summary
    summary_ids = model.generate(input_ids, num_beams=4, max_length=150, early_stopping=True)
    
    # Decode the generated summary
    summary = tokenizer.decode(summary_ids.squeeze(), skip_special_tokens=True)
    
    return summary

# %% [markdown]
# ## Getting the Summary for all the news Articles

# %%
for i in newsList:
    
    # Iterating over each News
    newsUrl = i
    
    r = requests.get(newsUrl, headers = headers)
    htmlContent = r.content
    newsSoup = BeautifulSoup(htmlContent, 'html.parser') 
    
    # Getting the Title of the News
    title = newsSoup.find('h1', class_ = 'hdg1').text
    print(title)
    print("\n")
    
    # Getting the Data of the News
    newsArticle = newsSoup.find('div', class_ = 'detail')
    
    # Finding the Data from the News
    if newsArticle:
        newsArticle = newsArticle.find_all("p")
        
        paragraph_text = ""
        
        # Storing the Data in paragraph_text
        for paragraph in newsArticle:
            paragraph_text += paragraph.get_text(strip=True) + " "
            
        paragraph_text = paragraph_text.strip()

        summary = gen_summary(paragraph_text)
    
        print(summary)
        
        print("\n")
        print("==========================================================X======================================================")
        print("\n")
  
    time.sleep(5)
# Out:
# Religious intolerance, press freedom: 75 US lawmakers ask Biden to raise rights issues with PM Modi
#
#
# 75 Democratic senators and members of the House of Representatives signed the letter. They said they were concerned about religious intolerance, press freedoms, internet access and the targeting of civil society groups. Modi left for Washington on Tuesday for avisit projected as a milestone in ties between the two countries.
#
#
# ==========================================================X======================================================
#
#
# 'Deepen people-to-people ties, address climate change': White House on Modi-Biden meet's outcomes
#
#
# PM Modi is on a state visit to the US. He is expected to hold talks on various issues with President Biden. The two leaders will also focus on strengthening and deepening people-to-people ties, adding that this factor will be guiding the relationship between the two countries in future.
#
#
# ==========================================================X======================================================
#
#
# ‘Modi's US visit to enhance bilateral ties, not about China, Russia’: White House
#
#
# The main objective of Prime Minister NarendraModi's visit to the United States is to strengthen the bilateral relationship. John Kirby, White House National Security Council Coordinator for Strategic Communications said that this visit is not about convincing PM Modi or the Indian Government to do something different. He said that the US supported "India's emergence as a great power" and was looking to improve and deepen the defence cooperation between India and US.
#
#
# ==========================================================X======================================================
#
#
# 50 booked for vandalising shops of Muslims, assaulting man in Uttarakhand
#
#
# The Uttarakhand Police on Tuesday booked 50-60 unidentified people for allegedly ransacking shops of Muslims in Nainital. On June 14, some residents of Lamachaur village in Haldwani claimed to having caught a 25-year-old Muslim man, identified as Hafiz, while having sex with a cow. The same day, the police arrested Hafiz and booked him under relevant sections of the Indian Penal Code.
#
#
# ==========================================================X======================================================
#
#
# Drugs regulator asks states to probe adverse event complaints related to India-made drugs
#
#
# Of the World Health Organisation’s medical product alert against 20 pharmaceutical products, mainly syrups against fever and cough, linked to around 300 deaths globally, seven are from India. At least 70 companies so far have been issued show-cause notice, of which 18 have had their licences suspended because of lapses found in manufacturing and other relevant processes.
#
#
# ==========================================================X======================================================
#
#
# As heatwave rages on, Centre rushes teams to UP and Bihar
#
#
# A team of experts from the Union health ministry, Indian Council of Medical Research (ICMR), India Meteorological Department (IMD) and National Disaster Management Authority (NDMA) will visit the states of Uttar Pradesh and Bihar. Heatwaves across swathes of Bihar and Uttar Pradesh have killed over 100 people.
#
#
# ==========================================================X======================================================
#
#
# Partners of first resort, support India’s emergence as great power: US
#
#
# John Kirby, coordinator for strategic communications at the US National Security Council (NSC) said that visit will stress that there is no partner “more consequential” than India in addressing global challenges. Kirby said that President Joe Biden will raise human rights issues with PM Modi, just as he consistently did with other global leaders.
#
#
# ==========================================================X======================================================
#
#
# Andhra: ‘Godman’ held for repeatedly raping girl, say police
#
#
# Swami Poornananda, 63, is accused of raping a 15-year-old girl at an ashram in Visakhapatnam. The victim, who lost her parents at an early age, was admitted to the ashram two years ago. She told the police that she was chained in a room, tortured and raped repeatedly by the accused.
#
#
# ==========================================================X======================================================
#
#
# Senate India caucus chief welcomes Modi, bats for stronger defence ties to counter China
#
#
# Senator Mark Warner is the co-chair of the India caucus in the US Senate. He said he will introduce legislation this week to include India in the North Atlantic Treaty Organisation (Nato)+5 arrangement to boost defence ties between the two countries. Warner said that China posed a challenge to both India and the US in a variety of ways.
#
#
# ==========================================================X======================================================
#
#
# Police bust fake MBBS degree racket at MP varsity, two arrested
#
#
# Pratiksha Dahima and her boyfriend, Mohammad Shafiq, were arrested for allegedly procuring a fake medical degree and marksheet. Police said the arrests helped unearth a fake-certificate racket in the city. The alleged racket came to light after a peon at the varsity issued a duplicate copy of the certificate to Dahima.
#
#
# ==========================================================X======================================================
#
#
# Punjab assembly passes bill to replace governor with CM as chancellor of state universities
#
#
# The Punjab assembly on Tuesday unanimously cleared the Punjab University Laws (Amendment) Bill, 2023. It paves the way to make the chief minister the chancellor of 12 state-run universities, replacing the governor from that position. Punjab became the fourth state to take this controversial decision after West Bengal, Tamil Nadu and Kerala.
#
#
# ==========================================================X======================================================
#
#
# Ram Lalla’s idol at Ayodhya temple likely to be installed on January 14 or 15
#
#
# A seven-day ceremony to install the idol of Ram Lalla in the sanctum -sanctorum of Ayodhya’s Ram temple is likely to begin on January 14 or 15. Members of the trust said the installation of the idol was unlikely to take place in December. Per the Hindu calendar, rituals can only occur from Makar Sankranti when the Sun moves from the southern hemisphere to the Northern.
#
#
# ==========================================================X======================================================
#
#
# New bill paves the way for Punjab govt to pick DGP
#
#
# The Punjab assembly on Tuesday passed the Punjab Police Amendment Bill, 2023. The Bill seeks to do away with the Supreme Court-mandated procedure to appoint the Director General of Police. As per the Bill, a seven-member committee, to be headed by a former chief justice or a retired judge of the Punjab & Haryana high court, will shortlist three senior-most officers from a pool of eligible officers.
#
#
# ==========================================================X======================================================
#
#
# Bengal foundation day event latest flashpoint in governor-govt tussle
#
#
# West Bengal governor CV Ananda Bose on Tuesday commemorated the state’s ‘foundation day’ Chief minister Mamata Banerjee raised strong objections raised by the governor. She pointed out the state was not founded on any particular day, least of all on June 20.
#
#
# ==========================================================X======================================================
#
#
# EC calls for increasing Assam’s reserved seats in draft proposal
#
#
# The number of assembly seats reserved for scheduled castes should be increased to nine from eight, the poll overseer said. For the Lok Sabha, it suggested reserving two seats for scheduled tribes and one seat for Scheduled Castes. The Election Commission has invited feedback on the proposal till July 11.
#
#
# ==========================================================X======================================================
#
#
# Opposition parties unlikely to ink common minimum programme at Patna meet
#
#
# Some key opposition parties are not comfortable with the idea of a CMP at this stage. A CMP is usually inked after an election. Media reports suggested that Nationalist Congress Party chief Sharad Pawar might be asked to draft a C MP. The meeting of opposition parties in Patna scheduled on June 23 will try to identify common issues.
#
#
# ==========================================================X======================================================
# CM Gehlot approves aid for research scholars
#
#
# Rajasthan chief minister Ashok Gehlot on Tuesday approved a proposal of ₹62.30 crore to provide financial assistance to around 6,000 research scholars in the state. “About 2200 research scholars of government colleges and universities receiving financial aid from the state government will be given a fellowship of₹20,000 per month,” the release said.
#
#
# ==========================================================X======================================================
#
#
# In a green agri push, cabinet nod likely for PM-Pranam, 2 schemes
#
#
# PM-Pranam is a scheme to hand out cash incentives to states that can cut their consumption of chemical soil nutrients. It is part of a broader policy push to limit fertilizer subsidies, and promote natural and organic farming. Food and fertiliser subsidies accounted for about an eighth of India’s budget worth nearly ₹39 lakh crore.
#
#
# ==========================================================X======================================================
#
#
# China blocks India’s bid to tag 26/11 plotter as terrorist
#
#
# Sajid Mir is wanted in connection with the 2008 Mumbai attacks. Mir has already been designated a terrorist under the laws of India and the US. China has repeatedly blocked efforts by India and its partners to designate Pakistan-based terrorists. Mir was LeT’s ‘operations manager’ for the Mumbai attacks, “playing a leading role in their planning, preparation, and execution”
#
#
# ==========================================================X======================================================
#
#
# Bengal panchayat elections: Violence breaks out on last day of nomination withdrawal
#
#
# TMC worker Benoy Barman sustained grievous injuries after he was attacked with sharp weapons by unidentified men at Dinhata in Cooch Behar. At Burdwan in Murshidabad district, TMC and Congress workers clashed with one another outside the block development office (BDO) The Congress alleged that their candidates were attacked by TMC workers.
#
#
# ==========================================================X======================================================
#
#
# Bengal panchayat elections: Supreme Court junks pleas against order on central forces
#
#
# The Supreme Court has approved deployment of central forces for the upcoming panchayat polls in West Bengal. It junked the petitions filed by the state government and the state election commission (SEC) against a Calcutta high court order in this regard. “Holding elections cannot be a license to commit violence. Elections cannot be accompanied with violence,” the court said.
#
#
# ==========================================================X======================================================
#
#
# UP, Bihar deaths indicate lapses in heat action plans
#
#
# Uttar Pradesh and Bihar have seen almost 100 deaths in the past five days on account of a heat wave. Uttar Pradesh’s standard operating procedure for heatwave management says government agencies should prepare for intense heat months in advance. Bihar heat action plan also focuses on closing shops during intense heat days, changing office and school timings.
#
#
# ==========================================================X======================================================
#
#
# CBI investigators may record statements of Shah Rukh, Aryan in Wankhede bribery case
#
#
# The extortion attempt is linked to the raid of a cruise ship off Mumbai in October 2021, and the arrest of Aryan Khan, despite no drugs being found on him. The Bombay high court has granted Wankhede interim protection from arrest till June 23. The CBI team is also currently analysing technical and documentary evidence such as WhatsApp chats of the accused.
#
#
# ==========================================================X======================================================
#
#
# Dissent brews against CM Biren Singh over violence in Manipur
#
#
# Rumblings against the N Biren Singh government grew louder in Manipur and New Delhi. Differences have emerged among BJP legislators on Singh’s handling of the issue. Manipur has been on the boil since May 3 witnessing widespread ethnic clashes. The violence has claimed at least 115 lives, injured over 300 and displaced as many as 40,000 people.
#
#
# ==========================================================X======================================================
#
#
# Defence, technology on agenda as PM Modi begins key US visit
#
#
# Prime Minister NarendraModi arrived in New York on Tuesday afternoon eastern time. He is in the US at the invitation of President Joe Biden and First Lady Jill Biden. Modi will lead the International Day of Yoga celebrations at the United Nations headquarters. He will then depart for Washington DC on Wednesday.
#
#
# ==========================================================X======================================================
#
#
# HC to review order on Meiteis in ST quota list
#
#
# The Manipur high court on Tuesday admitted a review petition seeking to modify its March 27 order. The high court had directed the state government to recommend inclusion of the Meitei community in the Scheduled Tribes (ST) list. The order sparked a wave of violence that continues to roil the northeastern state, and set off an exodus of the state’s two largest communities.
#
#
# ==========================================================X======================================================
#
#
# Will continue to meet India’s oil needs: Russian ambassador Denis Alipov tells HT
#
#
# Russia will continue meeting India’s energy needs as long as there is demand. The two sides are working on arrangements to make energy supplies sustainable. Russia has eclipsed traditional suppliers such as Saudi Arabia and Iraq, providing 7.94 million tonnes of crude in April. The surge in oil imports has, however, created a trade imbalance.
#
#
# ==========================================================X======================================================
#
#
# Elon Musk's meeting with Modi in US to discuss Tesla's India plans: Report
#
#
# Tesla chief executive Elon Musk will brief Indian Prime Minister Narendra Modi on plans to set up a manufacturing base there. The meeting, the first at a high level to discuss the expansion, will take place on Tuesday during Modi's state visit to the United States. Musk will discuss investment plans and outlook with Modi, the source said.
#
#
# ==========================================================X======================================================
#
#
# On Gita Press award, Congress' Adhir Ranjan Chowdhury says he was ‘kept in dark’
#
#
# Congress MP Adhir Ranjan Chowdhury alleged that he was “kept in the dark” about the Centre's decision to confer the Gandhi Peace Prize for 2021 on Gita Press. Chowdhry said that it is “nothing but the sheer autocratic attitude of this government, which has been very much explicit and evident in all their actions and reactions”
#
#
# ==========================================================X======================================================
#
#
# Watch: Indian women prepare garlands to welcome PM Modi in US
#
#
# The Indian diaspora is ready to welcome the leader with full fervour. The preparations included women making garlands with different kinds of flowers. PM Modi is also expected to meet personalities including astrophysicist Neil deGrasse Tyson, Tesla Chief Executive Elon Musk, and Grammy award-winning Indian-American singer Falu (Falguni Shah)
#
#
# ==========================================================X======================================================

# %% [markdown]
# ## Using HyperParameter Tuning for Optimal Results

# %%
from sklearn.model_selection import GridSearchCV

# Define the existing code for retrieving news articles and generating summaries
def retrieve_news_and_summarize(newsList):
    summaries = []
    
    for newsUrl in newsList:
        r = requests.get(newsUrl, headers=headers)
        htmlContent = r.content
        newsSoup = BeautifulSoup(htmlContent, 'html.parser')

        title = newsSoup.find('h1', class_='hdg1').text
        newsArticle = newsSoup.find('div', class_='detail')

        if newsArticle:
            newsArticle = newsArticle.find_all("p")
            paragraph_text = ""
            
            for paragraph in newsArticle:
                paragraph_text += paragraph.get_text(strip=True) + " "

            paragraph_text = paragraph_text.strip()

            summary = gen_summary(paragraph_text)
            summaries.append(summary)

            # print(summary)
            # print("=============================X===========================")

    return summaries

# Define the hyperparameter grid
hyperparameters = {
    'num_beams': [2, 4, 8],
    'max_length': [50, 100, 150]
}

# Create a scoring metric
scoring = 'rouge-n'

# Create a GridSearchCV object
grid_search = GridSearchCV(
    estimator=gen_summary,
    param_grid=hyperparameters,
    scoring=scoring,
    cv=5,
    n_jobs=-1
)

# Retrieve news articles and generate summaries
summaries = retrieve_news_and_summarize(newsList)

# Fit the GridSearchCV object
grid_search.fit(summaries, target_variable)  # Replace 'target_variable' with your target variable

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Print the best summary
best_summary = grid_search.best_estimator_.predict(paragraph_text)  # Replace 'paragraph_text' with your test data
print("Best Summary:", best_summary)
